# %% [markdown]
# # Taller 3 - Introducción al Machine Learning

# %% [markdown]
# # 1 - Bibliotecas
#
# Para la actividad se hacen uso de 5 bibliotecas:
#
# ## Visualización
# Para el área de visualización se han escogido las bibliotecas de Matplotlib y Seaborn, si bien es posible realizar todos los gráficos de seaborn con matplotlib, con seaborn, los gráficos se encuentran diseñados de forma que sean más agradables y sencillos de usar.
#
# ## Data wrangling
#
# La biblioteca por excelencia para el data wrangling es Pandas y se complementa perfectamente con NumPy que es una biblioteca especializada en el cálculo vectorial y sobre la cual está construida pandas.
#
# ## Machine Learning
#
# SciKit-Learn es tal vez la biblioteca más extendida al momento de trabajar con los diferentes algoritmos de Machine Learning, entre ellos random forest, esta. al igual que pandas, se encuentra construida sobre numpy lo que la hace bastante eficiente, además de todo esto, la biblioteca busca ser de alto nivel, es decir, sencilla de usar.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

from sklearn.preprocessing import LabelEncoder
from sklearn.tree import (
    DecisionTreeRegressor,
    DecisionTreeClassifier,
    export_text,
    plot_tree
)
from sklearn.model_selection import (
    train_test_split,
    GridSearchCV
)
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import NearestCentroid
from sklearn.metrics import (
    mean_squared_log_error,
    mean_absolute_error,
    mean_squared_error,
    confusion_matrix,
    accuracy_score
)
from sklearn.ensemble import (
    RandomForestRegressor,
    RandomForestClassifier
)

# %%
data = pd.read_csv('data/train.csv', index_col=0)
data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# ...            ...    ...               ...      ...   ...      ...
# 887              0      0            211536  13.0000   NaN        S
# 888              0      0            112053  30.0000   B42        S
# 889              1      2        W./C. 6607  23.4500   NaN        S
# 890              0      0            111369  30.0000  C148        C
# 891              0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %% [markdown]
# # 2 - Análisis de datos nulos

# %% [markdown]
# ## Conociendo los datos nulos
#
# Primero es necesario conocer los datos nulos que se puedan llegar a tener, que % de nulos hay por cada columna y que tipo de dato es

# %%
count_nan = data.isna().sum().sort_values(ascending=False)
count_nan = count_nan[count_nan != 0]

print(f' {("-"*56)}\n'
      f'| {"Columna":^15} | {"# Nulos":^9} | {"% Nulos":^9} | {"Tipo de dato":^12} |\n'
      f' {("-"*56)}'
     )

for c, n, p in zip(count_nan.index, count_nan, 1 - (data.shape[0] - count_nan) / data.shape[0]):
    print(f'| {c:<15} | {n:<9} | {round(p, 4):<9} | {str(data[c].dtypes):<12} |')
print(f' {("-"*56)}')
# Out:
#  --------------------------------------------------------
# |     Columna     |  # Nulos  |  % Nulos  | Tipo de dato |
#  --------------------------------------------------------
# | Cabin           | 687       | 0.771     | object       |
# | Age             | 177       | 0.1987    | float64      |
# | Embarked        | 2         | 0.0022    | object       |
#  --------------------------------------------------------

# %% [markdown]
# ## Tratamiento de nulos
#
# Para el análisis inicial de Machine Learning vamos a realizar un tratamiento básico de los datos nulos, posteriormente se puede hacer un tratamiento más profundo

# %%
cat_cols = data.select_dtypes(include=['object']).columns.tolist()
count_nan = data.isna().sum().sort_values(ascending=False)
count_nan = count_nan[count_nan != 0]


print(f' {("-"*42)}\n'
      f'| {"Columna":^15} | {"Valor nuevo":^22} |\n'
      f' {("-"*42)}'
     )

for c in count_nan.index:
    value = data[c].mode()[0] if data[c].dtypes == object else data[c].mean()
    print(f'| {c:<15} | {value:<22} |')
    data[c] = data[c].fillna(value=value)

print(f' {("-"*42)}')
# Out:
#  ------------------------------------------
# |     Columna     |      Valor nuevo       |
#  ------------------------------------------
# | Cabin           | B96 B98                |
# | Age             | 29.69911764705882      |
# | Embarked        | S                      |
#  ------------------------------------------

# %% [markdown]
# # 3 - Endocing
#
# Las variables categóricas no siempre son muy buenas para la construcción de modelos, para ello se tienen que transformar en numéricas, para lograr esto lo hacemos con `LabelEncoder`

# %%
num_cols = data.select_dtypes(include=['float64', 'int64']).columns.tolist()
cat_cols = data.select_dtypes(include='object').columns.tolist()

label_encoder = LabelEncoder()
label_encode = data[cat_cols].apply(label_encoder.fit_transform)
label_encode
# Out:
#              Name  Sex  Ticket  Cabin  Embarked
# PassengerId
# 1             108    1     523     47         2
# 2             190    0     596     81         0
# 3             353    0     669     47         2
# 4             272    0      49     55         2
# 5              15    1     472     47         2
# ...           ...  ...     ...    ...       ...
# 887           548    1     101     47         2
# 888           303    0      14     30         2
# 889           413    0     675     47         2
# 890            81    1       8     60         0
# 891           220    1     466     47         1
#
# [891 rows x 5 columns]

# %%
data[cat_cols]
# Out:
#                                                           Name     Sex  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                                     Allen, Mr. William Henry    male
# ...                                                        ...     ...
# 887                                      Montvila, Rev. Juozas    male
# 888                               Graham, Miss. Margaret Edith  female
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female
# 890                                      Behr, Mr. Karl Howell    male
# 891                                        Dooley, Mr. Patrick    male
#
#                        Ticket    Cabin Embarked
# PassengerId
# 1                   A/5 21171  B96 B98        S
# 2                    PC 17599      C85        C
# 3            STON/O2. 3101282  B96 B98        S
# 4                      113803     C123        S
# 5                      373450  B96 B98        S
# ...                       ...      ...      ...
# 887                    211536  B96 B98        S
# 888                    112053      B42        S
# 889                W./C. 6607  B96 B98        S
# 890                    111369     C148        C
# 891                    370376  B96 B98        Q
#
# [891 rows x 5 columns]

# %%
data_model = data.drop('Survived', axis=1)
num_cols.remove('Survived')
data_encode = np.append(data_model[num_cols], label_encode, axis=1)
data_encode = pd.DataFrame(data_encode, columns=num_cols + cat_cols)
data_encode
# Out:
#      Pclass        Age  SibSp  Parch     Fare   Name  Sex  Ticket  Cabin  \
# 0       3.0  22.000000    1.0    0.0   7.2500  108.0  1.0   523.0   47.0
# 1       1.0  38.000000    1.0    0.0  71.2833  190.0  0.0   596.0   81.0
# 2       3.0  26.000000    0.0    0.0   7.9250  353.0  0.0   669.0   47.0
# 3       1.0  35.000000    1.0    0.0  53.1000  272.0  0.0    49.0   55.0
# 4       3.0  35.000000    0.0    0.0   8.0500   15.0  1.0   472.0   47.0
# ..      ...        ...    ...    ...      ...    ...  ...     ...    ...
# 886     2.0  27.000000    0.0    0.0  13.0000  548.0  1.0   101.0   47.0
# 887     1.0  19.000000    0.0    0.0  30.0000  303.0  0.0    14.0   30.0
# 888     3.0  29.699118    1.0    2.0  23.4500  413.0  0.0   675.0   47.0
# 889     1.0  26.000000    0.0    0.0  30.0000   81.0  1.0     8.0   60.0
# 890     3.0  32.000000    0.0    0.0   7.7500  220.0  1.0   466.0   47.0
#
#      Embarked
# 0         2.0
# 1         0.0
# 2         2.0
# 3         2.0
# 4         2.0
# ..        ...
# 886       2.0
# 887       2.0
# 888       2.0
# 889       0.0
# 890       1.0
#
# [891 rows x 10 columns]

# %%
count_nan = data_encode.isna().sum().sort_values(ascending=False)
count_nan = count_nan[count_nan != 0]

print(f' {("-"*56)}\n'
      f'| {"Columna":^15} | {"# Nulos":^9} | {"% Nulos":^9} | {"Tipo de dato":^12} |\n'
      f' {("-"*56)}'
     )

for c, n, p in zip(count_nan.index, count_nan, 1 - (data.shape[0] - count_nan) / data.shape[0]):
    print(f'| {c:<15} | {n:<9} | {round(p, 4):<9} | {str(data_encode[c].dtypes):<12} |')
print(f' {("-"*56)}')
# Out:
#  --------------------------------------------------------
# |     Columna     |  # Nulos  |  % Nulos  | Tipo de dato |
#  --------------------------------------------------------
#  --------------------------------------------------------

# %% [markdown]
# # 4 - Conjuntos de entrenamiento y validación

# %%
x_train, x_test, y_train, y_test = train_test_split(data_encode, data['Survived'], test_size=.3, random_state=2)

# %% [markdown]
# # 5 - Construcción del Modelo: Árbol de Decisión
#
# Usaremos un modelo de **árbol de decisión** para predecir la supervivencia. El árbol de decisión es fácil de interpretar y una buena elección inicial para problemas de clasificación.
#
# Dividiremos los datos en un conjunto de entrenamiento y uno de prueba, para poder evaluar la capacidad predictiva del modelo.

# %% [markdown]
# ## Entrenamiento y Evaluación del Modelo
#
# Entrenamos el modelo y luego medimos su precisión en el conjunto de prueba.

# %%
def matriz_confusion(test, pred, nombre_modelo) -> None:
    
    cm  = confusion_matrix(test, pred)
    acs = accuracy_score(test, pred)
    acs *= 100

    plt.figure(figsize=(20, 5))
    sns.set_context("talk")
    sns.heatmap(cm, annot=True, cmap="Paired_r", linewidth=1, linecolor='w', fmt='.0f')
    plt.xlabel('Predicted Value')
    plt.ylabel('True Value')
    plt.suptitle(f'Matriz de Confusión | {nombre_modelo}')
    plt.text(0, 2.5, f'Accuracy score : {round(acs, 4)}%',verticalalignment='bottom')
    plt.show()

# %% [markdown]
# ### Árboles de decición
# Este fragmento implementa un modelo básico de árbol de decisión, que es fácil de interpretar y puede manejar tanto
# variables categóricas como numéricas.

# %%
# Entrenar el modelo de árbol de decisión
tree_model = DecisionTreeClassifier(random_state=42)
tree_model.fit(x_train, y_train)

# Predicción y evaluación
y_pred = tree_model.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
print(f'Precisión del modelo en el conjunto de prueba: {accuracy:.2f}')
# Out:
# Precisión del modelo en el conjunto de prueba: 0.77

# %% [markdown]
# Este código entrena un modelo de árbol de decisión con un conjunto de datos, realiza predicciones sobre un conjunto de prueba y evalúa la precisión del modelo. Este proceso es fundamental en el aprendizaje automático para garantizar que el modelo no solo aprenda bien los datos con los que fue entrenado, sino que también generalice adecuadamente a nuevos datos.

# %%
msle  = mean_squared_log_error(y_pred,y_test)
rmsle = np.sqrt(msle)

print('RMLSE for the data:',rmsle)
print('MAE:',mean_absolute_error(y_pred,y_test))
print('MSE:',mean_squared_error(y_pred,y_test))
# Out:
# RMLSE for the data: 0.3306914615169065
# MAE: 0.22761194029850745
# MSE: 0.22761194029850745

# %% [markdown]
# Estas métricas ofrecen una visión integral del desempeño del modelo, permitiendo a los desarrolladores y analistas identificar áreas de mejora y ajustar el modelo según sea necesario. La combinación de estas evaluaciones no solo ayuda a validar la efectividad del modelo actual, sino que también proporciona una base sólida para futuras iteraciones y refinamientos en el proceso de modelado.

# %%
 matriz_confusion(y_test, y_pred, 'Decision Tree Classifier')

# %% [markdown]
# Es una herramienta fundamental para evaluar el rendimiento de un modelo de clasificación. Permite visualizar el desempeño del modelo en términos de verdaderos positivos, verdaderos negativos, falsos positivos y falsos negativos. Esto proporciona una comprensión más profunda de cómo está funcionando el modelo más allá de las métricas simples como la precisión.
#
# <b>**Verdaderos Positivos (TP):</b>** Casos correctamente clasificados como positivos.
#
# <b>**Verdaderos Negativos (TN):</b>** Casos correctamente clasificados como negativos.
#
# <b>**Falsos Positivos (FP):</b>** Casos incorrectamente clasificados como positivos (también conocidos como errores tipo I).
#
# <b>**Falsos Negativos (FN):</b>** Casos incorrectamente clasificados como negativos (errores tipo II).

# %%
plt.figure(figsize=(30,20))
fig = plot_tree(tree_model, filled=True)
plt.savefig('tree_high_dpi', dpi=300)

# %% [markdown]
# Este bloque de código configura una visualización detallada de un árbol de decisión, asegurando que sea legible y estéticamente agradable. Al guardar la imagen en alta resolución, permite su uso en diferentes contextos, como informes o presentaciones, facilitando así la comunicación de los resultados del modelo. La visualización del árbol es fundamental para entender cómo el modelo toma decisiones basadas en las características de los datos.

# %% [markdown]
# ### Naive Bayes

# %%
# Entrenar el modelo de Naive bayes
gnb_model = GaussianNB()
gnb_model.fit(x_train, y_train)

# Predicción y evaluación
y_pred = gnb_model.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
print(f'Precisión del modelo en el conjunto de prueba: {accuracy:.2f}')
# Out:
# Precisión del modelo en el conjunto de prueba: 0.80

# %% [markdown]
# En este bloque de código entrena un modelo de clasificación utilizando Naive Bayes Gaussiano y evalúa su rendimiento en un conjunto de prueba. Este enfoque es particularmente útil para problemas de clasificación en los que se desea un modelo rápido y eficiente. La precisión obtenida proporciona una medida clara del desempeño del modelo, permitiendo identificar su efectividad en la tarea de clasificación.

# %%
msle  = mean_squared_log_error(y_pred,y_test)
rmsle = np.sqrt(msle)

print('RMLSE for the data:',rmsle)
print('MAE:',mean_absolute_error(y_pred,y_test))
print('MSE:',mean_squared_error(y_pred,y_test))
# Out:
# RMLSE for the data: 0.3111393527573529
# MAE: 0.20149253731343283
# MSE: 0.20149253731343283

# %% [markdown]
# Este bloque de código calcula y muestra varias métricas clave para evaluar el rendimiento de un modelo:
#
# **RMSLE (Raíz del Error Cuadrático Logarítmico Medio):** Proporciona una medida ajustada para errores logarítmicos, útil en contextos donde se desea penalizar más las subestimaciones.
#
# ***MAE (Error Absoluto Medio):*** Indica el error promedio absoluto, ofreciendo una interpretación clara del rendimiento del modelo.
#
# ***MSE (Error Cuadrático Medio):*** Mide el error cuadrático promedio, penalizando más fuertemente los errores grandes.
# Estas métricas son fundamentales para entender cómo se comporta el modelo con respecto a los datos reales y ayudan a guiar mejoras en su desempeño. Aunque estas métricas son típicamente utilizadas en contextos de regresión, si estás aplicando un modelo de clasificación, podría ser más apropiado considerar métricas específicas como precisión, recall o F1-score.

# %% [markdown]
# ### Nearest Centroid Classifier

# %%
# Entrenar el modelo de Nearest Centroid Classifier
gnb_model = NearestCentroid()
gnb_model.fit(x_train, y_train)

# Predicción y evaluación
y_pred = gnb_model.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
print(f'Precisión del modelo en el conjunto de prueba: {accuracy:.2f}')
# Out:
# Precisión del modelo en el conjunto de prueba: 0.58

# %% [markdown]
# La impresión de la precisión del modelo proporciona una medida clara de su rendimiento en el conjunto de prueba. Un valor alto indica que el modelo ha logrado clasificar correctamente una gran parte de los datos, lo cual es un buen indicativo de su efectividad.

# %%
msle  = mean_squared_log_error(y_pred,y_test)
rmsle = np.sqrt(msle)

print('RMLSE for the data:',rmsle)
print('MAE:',mean_absolute_error(y_pred,y_test))
print('MSE:',mean_squared_error(y_pred,y_test))
# Out:
# RMLSE for the data: 0.45008784620486164
# MAE: 0.4216417910447761
# MSE: 0.4216417910447761

# %% [markdown]
# En este bloque de código se han calculado y presentado varias métricas clave para evaluar el rendimiento de un modelo de regresión, aunque también pueden ser aplicables en contextos de clasificación dependiendo del tipo de problema y los datos utilizados.

# %% [markdown]
# ## Conclusiones

# %% [markdown]
# El análisis concluye que se utilizaron cinco bibliotecas principales para el trabajo de visualización, manipulación de datos y Machine Learning: Matplotlib y Seaborn para visualización, Pandas y NumPy para manipulación de datos, y SciKit-Learn para algoritmos de Machine Learning. Se identificó la importancia de manejar los datos nulos y transformar variables categóricas en numéricas mediante LabelEncoder.
#
# Se implementaron modelos de clasificación, destacando el árbol de decisión con una precisión del 77% y Naive Bayes, que alcanzó un 80%. También se utilizó el Nearest Centroid Classifier, que mostró una menor precisión del 58%. Las métricas evaluadas, como RMLSE, MAE y MSE, proporcionaron una visión integral del rendimiento del modelo, permitiendo identificar áreas de mejora y establecer una base para futuras iteraciones en el proceso de modelado. La visualización del árbol de decisión fue fundamental para entender las decisiones del modelo
